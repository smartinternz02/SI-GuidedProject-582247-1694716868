# %% [markdown]
# 21BCE3056 Rudranil Ghosh

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("winequality-red.csv")
print(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(df)

# Create a new DataFrame with normalized data
data_normalized_df = pd.DataFrame(data_normalized, columns=df.columns)

# Display the normalized data
print(data_normalized_df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.247788          0.397260         0.00        0.068493   0.106845
# 1          0.283186          0.520548         0.00        0.116438   0.143573
# 2          0.283186          0.438356         0.04        0.095890   0.133556
# 3          0.584071          0.109589         0.56        0.068493   0.105175
# 4          0.247788          0.397260         0.00        0.068493   0.106845
# ...             ...               ...          ...             ...        ...
# 1594       0.141593          0.328767         0.08        0.075342   0.130217
# 1595       0.115044          0.294521         0.10        0.089041   0.083472
# 1596       0.150442          0.267123         0.13        0.095890   0.106845
# 1597       0.115044          0.359589         0.12        0.075342   0.105175
# 1598       0.123894          0.130137         0.47        0.184932   0.091820
#
# ...

# %%
## minmax scaler is used to scale or normalize hte values between 0 and 1

# %%
df.isna() ##for null vales
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'data' is the DataFrame

# Univariate analysis - distribution of each feature
for column in df.columns:
    plt.figure(figsize=(8, 5))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

# %%
# Pairplot for multivariate analysis
sns.pairplot(df, diag_kind='kde')
plt.suptitle('Pairplot of Features', y=1.02)
plt.show()
## providing insights into how features relate to each other and how they are distributed individually.

# %%
correlation = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
## if the values close to 1 then we can say that the values is positively coorelated to the data 
## if the values is close to -1 then we can say that the data is -vely coorelated to the data.
## if the value is close to 0 we can say that the value is not so coorelated to thew data
## if value 1 is nothiun but the coorealtion to itself

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Assuming 'X' contains features and 'y' contains the target variable 'quality'
x = df.drop('quality', axis=1)
y = df['quality']

# Spliting the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Building the learning model
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
## test size is like weea re using 80% of the data for trainign random_state=42 give the random values
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Predicting the test set
y_pred = model.predict(x_test)

# Evaluating the model
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)

# Printing a classification report for detailed evaluation
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.659375
# Classification Report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00        10
#            5       0.72      0.75      0.73       130
#            6       0.63      0.69      0.66       132
#            7       0.63      0.52      0.57        42
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.66       320
#    macro avg       0.33      0.33      0.33       320
# weighted avg       0.63      0.66      0.64       320
# /Users/kishore/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
## 65.94% of the predictions made by the model on the test set were correct.

# %%
import numpy as np

# Assuming 'random_observation' is a numpy array representing a random observation
random_observation = np.array([7.5, 0.6, 0.1, 2.5, 0.078, 10, 40, 0.997, 3.35, 0.6, 10])

# Reshape the observation to match the model's expected input shape
random_observation = random_observation.reshape(1, -1)

# Predict wine quality for the random observation
predicted_quality = model.predict(random_observation)
print('Predicted Wine Quality for the Random Observation:', predicted_quality)
# Out:
# Predicted Wine Quality for the Random Observation: [5]
# /Users/kishore/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
